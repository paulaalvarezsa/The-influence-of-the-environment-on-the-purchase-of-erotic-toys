# %%
import pandas as pd

# %%
df_moon = pd.read_csv('df_melted.csv')

# %%
pd.read_csv('oil_clean.csv', decimal=',').to_csv('oil_clean.csv', index=False)

# %%
pd.read_csv('oil_clean.csv')
# Out:
#           Fecha  Último
# 0    2022-12-30   85.91
# 1    2022-12-29   82.26
# 2    2022-12-28   83.26
# 3    2022-12-27   84.68
# 4    2022-12-23   84.50
# ..          ...     ...
# 248  2022-01-14   86.06
# 249  2022-01-13   84.47
# 250  2022-01-12   84.67
# 251  2022-01-11   83.72
# 252  2022-01-10   80.87
#
# [253 rows x 2 columns]

# %%
df = pd.read_csv('sales_clean.csv', decimal=',')

# %%
df['Ingreso neto'].replace({'\.': '', ',': '.'}, regex=True).astype(float)
# Out:
# 0      2650.79
# 1      4727.17
# 2      7037.96
# 3      4882.08
# 4      4512.06
#         ...
# 360    2017.84
# 361    1506.94
# 362    1161.39
# 363    2019.46
# 364     815.81
# Name: Ingreso neto, Length: 365, dtype: float64

# %%
import csv
from io import StringIO

byte_content = b"iam byte content"
content = byte_content.decode()
file = StringIO(content)
csv_data = csv.reader(file, delimiter=",")

# %%
df = pd.read_csv('sales_clean_3.csv')

# %%
df.head()
# Out:
#        Diario                                   Da de la Semana  \
# 0  2022-01-01       b'\xff\xfes\x00\x87\x00b\x00a\x00d\x00o\x00'
# 1  2022-02-01     b'\xff\xfed\x00o\x00m\x00i\x00n\x00g\x00o\x00'
# 2  2022-03-01               b'\xff\xfel\x00u\x00n\x00e\x00s\x00'
# 3  2022-04-01          b'\xff\xfem\x00a\x00r\x00t\x00e\x00s\x00'
# 4  2022-05-01  b'\xff\xfem\x00i\x00\x8e\x00r\x00c\x00o\x00l\x...
#
#                                     Mes  Pedidos  \
# 0  b'\xff\xfee\x00n\x00e\x00r\x00o\x00'       62
# 1  b'\xff\xfee\x00n\x00e\x00r\x00o\x00'       99
# 2  b'\xff\xfee\x00n\x00e\x00r\x00o\x00'      165
# 3  b'\xff\xfee\x00n\x00e\x00r\x00o\x00'      125
# 4  b'\xff\xfee\x00n\x00e\x00r\x00o\x00'       96
#
#                                          Facturacin  \
# 0  b'\xff\xfe3\x00.\x002\x004\x000\x00,\x008\x006...
# 1  b'\xff\xfe5\x00.\x006\x006\x005\x00,\x002\x009...
# 2  b'\xff\xfe8\x00.\x005\x007\x005\x00,\x006\x003...
# 3  b'\xff\xfe5\x00.\x009\x002\x005\x00,\x007\x005...
# ...

# %%
df[['Diario', 'Mes']].applymap(lambda x: StringIO(byte_content.decode(x)))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11596\1722960196.py in <module>
# ----> 1 df[['Diario', 'Mes']].applymap(lambda x: StringIO(byte_content.decode(x)))
#
# c:\Users\Paula\anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func, na_action, **kwargs)
#    8931             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    8932
# -> 8933         return self.apply(infer).__finalize__(self, "applymap")
#    8934
#    8935     # ----------------------------------------------------------------------
#
# c:\Users\Paula\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ...

# %%
#df.to_csv('sales_clean.csv', index=False)
